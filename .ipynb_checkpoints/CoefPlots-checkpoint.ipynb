# %%
import numpy as np
import pandas as pd
import seaborn as sns

import os
import sys
import string

import statsmodels.api as sm
import statsmodels.formula.api as sms

import matplotlib as mpl
mpl.rc('text', usetex=False)

# %matplotlib inline

import matplotlib.pyplot as plt


# %load_ext autoreload

# %autoreload 2

# %% [markdown]
# ### CoefPlot
#
# The aim is to create coefficient plots like this, in order to present regression results alongwith additional details. This figure is generated from dummy data. The coefficients themselves are meaningless.
#
# <div align="center"> <img src="./docs/test.png" height="300"> </div>
#
# Here is another example, used in a current working paper.
#
# <div align="center"> <img src="./docs/Nigeria_h6.png" height="300"> </div>

# %% [markdown]
# **1. Generate some regression results**
#
# - First, create some dummy regression results for the example.
# - I use the Iris dataset for this notebook

# %%
from sklearn import datasets

def get_reg_data(result_obj, rounding=3):
    """
    Helper function to get regression results into a dataframe
    """
    reg_result=pd.concat([result_obj.params, 
                      result_obj.pvalues, 
                      result_obj.conf_int()], axis=1)
    
    reg_result.columns=['coef', 'pvalue', 'ci_left', 'ci_right']
    reg_result['ci_length']=reg_result['coef']-reg_result['ci_left']
    reg_result=reg_result.round(rounding)
    return reg_result

#load the Iris Dataset
iris=datasets.load_iris()

iris=pd.DataFrame(np.concatenate([iris.data, 
                             iris.target.reshape([-1, 1])], axis=1))

iris.columns=['sepal_length', 
              'sepal_width', 
              'petal_length', 
              'petal_width', 
              'iris_type']

iris=pd.concat([iris, pd.get_dummies(iris['iris_type'].astype(int), 
                                     prefix='type')], axis=1)


#Run a simple OLS Regression. The coefficients are meaningless, this is just for the sake of getting some data. 
reg=sms.ols('sepal_length~sepal_width+petal_length+petal_width+type_1+type_2', 
                   data=iris).fit(cov_type='HC1')


#get regression results in a pandas dataframe
reg_result=get_reg_data(reg)

#add in some additional columns with random data, to add additional columns to the table 
for i in range(4):
    reg_result[f'randcol{i}']=np.random.random(len(reg_result)).round(3)

reg_result
# Out:
#                coef  pvalue  ci_left  ci_right  ci_length  randcol0  randcol1  \
# Intercept     2.171   0.000    1.687     2.655      0.484     0.935     0.627
# sepal_width   0.496   0.000    0.339     0.653      0.157     0.880     0.719
# petal_length  0.829   0.000    0.688     0.970      0.141     0.099     0.622
# petal_width  -0.315   0.055   -0.637     0.007      0.322     0.798     0.726
# type_1       -0.724   0.002   -1.189    -0.258      0.465     0.301     0.666
# type_2       -1.023   0.003   -1.705    -0.342      0.681     0.241     0.413
#
#               randcol2  randcol3
# Intercept        0.146     0.709
# sepal_width      0.588     0.130
# petal_length     0.749     0.438
# petal_width      0.436     0.179
# type_1           0.133     0.860
# type_2           0.851     0.543

# %% [markdown]
# **2.  Import the module, and define all parameters for the plot.**
#
# The ***make_coef_plot*** function in the **CoefPlots** module is a wrapper for a number of matplotlib functions, which generates the coefficient plots + table as shown above. This is still a work in progress.
#
# There are 5 required parameters (see the function docstring for more details).
#
#    - ***x***: Coefficient values
#    - ***xerror***: 95% confidence interval lengths (xerror) -- roughly $1.96*\mbox{std. error}$. The *get_reg_data* function written above extracts this from the regression results.
#    - ***ylabels***: Coefficient Labels
#    - ***tabledata***: Data for the table. Matplotlib requires the data to be an ndarray, so I get these from the *reg_result*              dataframe (Created above)
#    - ***col_names***: Column Names for the table -- a dictionary of the variable names from *reg_result*, and the desired column names.

# %%
import CoefPlots as cpl

# %%
#Sort to keep the Intercept value at the bottom
reg_result['sort']=np.arange(1,len(reg_result)+1)

x=reg_result['coef'].values

xerror=reg_result['ci_length'].values

ylabels=['Intercept', 
         'Sepal Width', 
         'Petal Length', 
         'Petal Width', 
         'Iris Type 1 Random Long String',
         'Iris Type 2']

#Pick 4 columns to visualize
col_dict={
    'coef': "Coef.",
 'pvalue': "p-val",
 'ci_left': "ci:left",
 'ci_right': "ci:right"}


tabledata=reg_result.sort_values('sort', ascending=False)[col_dict.keys()].values

#display
tabledata
# Out:
# array([[-1.023e+00,  3.000e-03, -1.705e+00, -3.420e-01],
#        [-7.240e-01,  2.000e-03, -1.189e+00, -2.580e-01],
#        [-3.150e-01,  5.500e-02, -6.370e-01,  7.000e-03],
#        [ 8.290e-01,  0.000e+00,  6.880e-01,  9.700e-01],
#        [ 4.960e-01,  0.000e+00,  3.390e-01,  6.530e-01],
#        [ 2.171e+00,  0.000e+00,  1.687e+00,  2.655e+00]])

# %% [markdown]
# **Plot 1**
# - Generate Coefficient Plot with Default Formatting
# - Add Table (on the right of the plot) with 4 columns

# %%
fig=cpl.make_coef_plot(x, 
                       xerror, 
                       ylabels, 
                       tabledata, 
                       col_dict).show()

# %% [markdown]
# **Plot 2**
# - Generate Coefficient Plot with Default Formatting
# - Add Table (on the left of the plot) with 4 columns

# %%
fig=cpl.make_coef_plot(x, 
                   xerror, 
                   ylabels, 
                   tabledata, 
                   col_dict, 
                   table_position="left").save("test.png").show()

# %% [markdown]
# **Plot 3**
# - Generate Coefficient Plot with Default Formatting
# - Add Table (on the right of the plot), increase number of columns to 8

# %%
col_dict={
    'coef': "Coef.",
 'pvalue': "p-val",
 'ci_left': "ci:left",
 'ci_right': "ci:right",
 'randcol0': "rand\ncol1",
 'randcol1': "rand\ncol2",
 'randcol2': "rand\ncol3",
 'randcol3': "rand\ncol4"
}
tabledata=reg_result.sort_values('sort', ascending=False)[col_dict.keys()].values

fig=cpl.make_coef_plot(x, 
               xerror, 
               ylabels, 
               tabledata, 
               col_dict).save("test.png").show()

# %% [markdown]
# **Plot 4**
# - Same plot as above, but with custom formatting
# - Any matplotlib formatting options can be passed through "kwarg_dict", for the respective parts of the plot

# %%
#change the color and size of the markers, and color + linestyle of the errorbars.

fig=cpl.make_coef_plot(x, 
                   xerror, 
                   ylabels, 
                   tabledata, 
                   col_dict,  
                  kwarg_dict={"marker_kwargs":{"fmt":"bs", "markersize":6}, 
                              "errorbar_kwargs":{"ecolor":"grey", "elinewidth":2, "capsize":7,  "capthick":2}, 
                              "ylabel_kwargs":{"fontsize":13}}).\
            save("test.png").show()

# %% [markdown]
# **Plot 5**
#
# - Same figure as above
# - Add in figure title
# - Add in figure notes

# %%
#change the color and size of the markers, and color + linestyle of the errorbars.

fignotes="""Lorem ipsum dolor sit amet, consectetur adipiscing elit, 
sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. 
Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat."""

fig=cpl.make_coef_plot(x, 
                   xerror, 
                   ylabels, 
                   tabledata, 
                   col_dict,  
                  kwarg_dict={"marker_kwargs":{"fmt":"bs", "markersize":6}, 
                              "errorbar_kwargs":{"ecolor":"grey", "elinewidth":2, "capsize":7,  "capthick":2}, 
                              "ylabel_kwargs":{"fontsize":13}, 
                             "table_kwargs":{"fontsize":10}}).\
            title("Figure 1").\
            annotate(-0.25, -0.2, f"Notes: {fignotes}", **{"fontsize":"10", "ha":"left"}).\
            save("test.png").show()

# %% [markdown]
# **Plot 6**
#
# - use Latex formatting in the y labels
# - Note that this slows down the whole thing.

# %%
mpl.rc('text', usetex=True)


x=reg_result['coef'].values

xerror=reg_result['ci_length'].values

col_dict={
    'coef': "Coef.",
 'pvalue': "p-val",
 'ci_left': "ci:left",
 'ci_right': "ci:right"}

tabledata=reg_result.sort_values('sort', ascending=False)[col_dict.keys()].values
ylabels=['\\textbf{Intercept}', 
         '\\textit{Sepal Width}', 
         'Petal Length', 
         '\\emph{Petal Width}', 
         'Iris Type 1 Random Long String',
         'Iris Type 2']

fig=cpl.make_coef_plot(x,  
                       xerror, 
                       ylabels, 
                       tabledata, 
                       col_dict, 
                      table_position="right", 
                      kwarg_dict={"marker_kwargs":{"fmt":"bs", "markersize":6}, 
                                  "errorbar_kwargs":{"color":"gray"}}).\
        save("test.png", bbox_inches = "tight").show()

# %% [markdown]
# **Plot 6**
#
# - Another example with Latex labels/ different formatting.
# - Create a longer figure. (More labels on the y axis.)

# %%
## First, generate a new regression results dataset which is longer .
# For the sake of simplicity, simply duplicate the regression results dataset from above and stack it, 
# so we get 12 labels on the y axis. 

indexnames=list(reg_result.index)
indexnames.extend([f"{n}_1" for n in reg_result.index])

reg_result1=reg_result.append(reg_result)
reg_result1.index=indexnames

reg_result1['sort']=np.arange(1, len(reg_result1)+1)
reg_result1
# Out:
#                  coef  pvalue  ci_left  ci_right  ci_length  randcol0  \
# Intercept       2.171   0.000    1.687     2.655      0.484     0.935
# sepal_width     0.496   0.000    0.339     0.653      0.157     0.880
# petal_length    0.829   0.000    0.688     0.970      0.141     0.099
# petal_width    -0.315   0.055   -0.637     0.007      0.322     0.798
# type_1         -0.724   0.002   -1.189    -0.258      0.465     0.301
# type_2         -1.023   0.003   -1.705    -0.342      0.681     0.241
# Intercept_1     2.171   0.000    1.687     2.655      0.484     0.935
# sepal_width_1   0.496   0.000    0.339     0.653      0.157     0.880
# petal_length_1  0.829   0.000    0.688     0.970      0.141     0.099
# petal_width_1  -0.315   0.055   -0.637     0.007      0.322     0.798
# type_1_1       -0.724   0.002   -1.189    -0.258      0.465     0.301
# type_2_1       -1.023   0.003   -1.705    -0.342      0.681     0.241
#
#                 randcol1  randcol2  randcol3  sort
# ...

# %%
### Example using Latex text labels

mpl.rc('text', usetex=True)

x=reg_result1['coef'].values

xerror=reg_result1['ci_length'].values

col_dict={
    'coef': "\\textbf{Coef.}",
 'pvalue': "\\textbf{p-val}",
 'ci_left': "\\textbf{ci: left}",
 'ci_right': "\\textbf{ci: right}"}

tabledata=reg_result1.sort_values('sort', ascending=False)[col_dict.keys()].values

ylabels=['\\textbf{Intercept}', 
         '\\textit{Sepal Width}', 
         'Petal Length', 
         '\\emph{Petal Width}', 
         'Iris Type 1 Random Long String',
         'Iris Type 2',
        '\\textbf{Intercept 1}', 
         '\\textit{Sepal Width 1}', 
         'Petal Length 1', 
         '\\emph{Petal Width 1}', 
         'Iris Type 1 Random Long String 1',
         'Iris Type 2 1']



#Generate Coefficient Plot
fig=cpl.make_coef_plot(x, 
                       xerror, 
                       ylabels, 
                       tabledata, 
                       col_dict, 
                        kwarg_dict={"marker_kwargs":{"fmt":"ws", "markersize":6, "markeredgecolor":"green"}, 
                              "errorbar_kwargs":{"color":"orange"}}).\
            title("\\emph{Panel A: Iris Fake Regression Results}", **{"fontsize":14}).\
            save("test.png", bbox_inches = "tight").show()
